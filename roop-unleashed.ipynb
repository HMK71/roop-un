# %% [markdown]
# # Colab for roop-unleashed - Gradio version
# https://github.com/ravindergandhi/roop-un

# %% [markdown]
# Install CUDA V11.8 on Google Cloud Compute

# %%
# !apt-get -y update
# !apt-get -y install cuda-toolkit-11-8
import os
os.environ["LD_LIBRARY_PATH"] += ":" + "/usr/local/cuda-11/lib64"
os.environ["LD_LIBRARY_PATH"] += ":" + "/usr/local/cuda-11.8/lib64"
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,285 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,647 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,625 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,520 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,861 kB]
# Fetched 17.3 MB in 5s (3,165 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   cuda-cccl-11-8 cuda-command-line-tools-11-8 cuda-compiler-11-8 cuda-cudart-11-8
#   cuda-cudart-dev-11-8 cuda-cuobjdump-11-8 cuda-cupti-11-8 cuda-cupti-dev-11-8 cuda-cuxxfilt-11-8
#   cuda-documentation-11-8 cuda-driver-dev-11-8 cuda-gdb-11-8 cuda-libraries-11-8
#   cuda-libraries-dev-11-8 cuda-memcheck-11-8 cuda-nsight-11-8 cuda-nsight-compute-11-8
#   cuda-nsight-systems-11-8 cuda-nvcc-11-8 cuda-nvdisasm-11-8 cuda-nvml-dev-11-8 cuda-nvprof-11-8
#   cuda-nvprune-11-8 cuda-nvrtc-11-8 cuda-nvrtc-dev-11-8 cuda-nvtx-11-8 cuda-nvvp-11-8
#   cuda-profiler-api-11-8 cuda-sanitizer-11-8 cuda-toolkit-11-8-config-common
#   cuda-toolkit-11-config-common cuda-tools-11-8 cuda-visual-tools-11-8 default-jre
#   default-jre-headless fonts-dejavu-core fonts-dejavu-extra gds-tools-11-8 libatk-wrapper-java
#   libatk-wrapper-java-jni libcublas-11-8 libcublas-dev-11-8 libcufft-11-8 libcufft-dev-11-8
#   libcufile-11-8 libcufile-dev-11-8 libcurand-11-8 libcurand-dev-11-8 libcusolver-11-8
#   libcusolver-dev-11-8 libcusparse-11-8 libcusparse-dev-11-8 libfontenc1 libnpp-11-8
#   libnpp-dev-11-8 libnvjpeg-11-8 libnvjpeg-dev-11-8 libtinfo5 libxcb-icccm4 libxcb-image0
#   libxcb-keysyms1 libxcb-render-util0 libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1
#   libxkbcommon-x11-0 libxkbfile1 libxtst6 libxxf86dga1 nsight-compute-2022.3.0
#   nsight-systems-2022.4.2 openjdk-11-jre x11-utils
# Suggested packages:
#   mesa-utils
# The following NEW packages will be installed:
#   cuda-cccl-11-8 cuda-command-line-tools-11-8 cuda-compiler-11-8 cuda-cudart-11-8
#   cuda-cudart-dev-11-8 cuda-cuobjdump-11-8 cuda-cupti-11-8 cuda-cupti-dev-11-8 cuda-cuxxfilt-11-8
#   cuda-documentation-11-8 cuda-driver-dev-11-8 cuda-gdb-11-8 cuda-libraries-11-8
#   cuda-libraries-dev-11-8 cuda-memcheck-11-8 cuda-nsight-11-8 cuda-nsight-compute-11-8
#   cuda-nsight-systems-11-8 cuda-nvcc-11-8 cuda-nvdisasm-11-8 cuda-nvml-dev-11-8 cuda-nvprof-11-8
#   cuda-nvprune-11-8 cuda-nvrtc-11-8 cuda-nvrtc-dev-11-8 cuda-nvtx-11-8 cuda-nvvp-11-8
#   cuda-profiler-api-11-8 cuda-sanitizer-11-8 cuda-toolkit-11-8 cuda-toolkit-11-8-config-common
#   cuda-toolkit-11-config-common cuda-tools-11-8 cuda-visual-tools-11-8 default-jre
#   default-jre-headless fonts-dejavu-core fonts-dejavu-extra gds-tools-11-8 libatk-wrapper-java
#   libatk-wrapper-java-jni libcublas-11-8 libcublas-dev-11-8 libcufft-11-8 libcufft-dev-11-8
#   libcufile-11-8 libcufile-dev-11-8 libcurand-11-8 libcurand-dev-11-8 libcusolver-11-8
#   libcusolver-dev-11-8 libcusparse-11-8 libcusparse-dev-11-8 libfontenc1 libnpp-11-8
#   libnpp-dev-11-8 libnvjpeg-11-8 libnvjpeg-dev-11-8 libtinfo5 libxcb-icccm4 libxcb-image0
#   libxcb-keysyms1 libxcb-render-util0 libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1
#   libxkbcommon-x11-0 libxkbfile1 libxtst6 libxxf86dga1 nsight-compute-2022.3.0
#   nsight-systems-2022.4.2 openjdk-11-jre x11-utils
# 0 upgraded, 75 newly installed, 0 to remove and 52 not upgraded.
# Need to get 2,715 MB of archives.
# After this operation, 6,662 MB of additional disk space will be used.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cccl-11-8 11.8.89-1 [1,040 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre-headless amd64 2:1.11-72build2 [3,042 B]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre amd64 11.0.25+9-1ubuntu1~22.04 [216 kB]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cupti-11-8 11.8.87-1 [15.4 MB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre amd64 2:1.11-72build2 [896 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libtinfo5 amd64 6.3-2ubuntu0.1 [100 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:19 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cupti-dev-11-8 11.8.87-1 [2,552 kB]
# Get:20 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvdisasm-11-8 11.8.86-1 [50.8 MB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:27 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cuobjdump-11-8 11.8.86-1 [165 kB]
# Get:28 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-gdb-11-8 11.8.86-1 [4,138 kB]
# Get:29 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-memcheck-11-8 11.8.86-1 [142 kB]
# Get:30 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvprof-11-8 11.8.87-1 [1,959 kB]
# Get:31 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvtx-11-8 11.8.86-1 [51.3 kB]
# Get:32 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-sanitizer-11-8 11.8.86-1 [8,784 kB]
# Get:33 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-command-line-tools-11-8 11.8.0-1 [2,472 B]
# Get:34 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cuxxfilt-11-8 11.8.86-1 [189 kB]
# Get:35 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-toolkit-11-config-common 11.8.89-1 [16.4 kB]
# Get:36 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-toolkit-11-8-config-common 11.8.89-1 [16.3 kB]
# Get:37 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cudart-11-8 11.8.89-1 [165 kB]
# Get:38 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-driver-dev-11-8 11.8.89-1 [27.3 kB]
# Get:39 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cudart-dev-11-8 11.8.89-1 [820 kB]
# Get:40 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvcc-11-8 11.8.89-1 [43.5 MB]
# Get:41 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvprune-11-8 11.8.86-1 [58.1 kB]
# Get:42 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-compiler-11-8 11.8.0-1 [2,432 B]
# Get:43 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-documentation-11-8 11.8.86-1 [49.8 kB]
# Get:44 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvrtc-11-8 11.8.89-1 [16.4 MB]
# Get:45 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcublas-11-8 11.11.3.6-1 [248 MB]
# Get:46 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufft-11-8 10.9.0.58-1 [94.2 MB]
# Get:47 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufile-11-8 1.4.0.31-1 [474 kB]
# Get:48 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcurand-11-8 10.3.0.86-1 [42.2 MB]
# Get:49 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusolver-11-8 11.4.1.48-1 [52.3 MB]
# Get:50 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusparse-11-8 11.7.5.86-1 [116 MB]
# Get:51 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnpp-11-8 11.8.0.86-1 [102 MB]
# Get:52 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjpeg-11-8 11.9.0.86-1 [1,865 kB]
# Get:53 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-libraries-11-8 11.8.0-1 [2,518 B]
# Get:54 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-profiler-api-11-8 11.8.86-1 [18.5 kB]
# Get:55 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvrtc-dev-11-8 11.8.89-1 [13.5 MB]
# Get:56 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcublas-dev-11-8 11.11.3.6-1 [269 MB]
# Get:57 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufft-dev-11-8 10.9.0.58-1 [189 MB]
# Get:58 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufile-dev-11-8 1.4.0.31-1 [1,062 kB]
# Get:59 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcurand-dev-11-8 10.3.0.86-1 [42.9 MB]
# Get:60 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusolver-dev-11-8 11.4.1.48-1 [35.7 MB]
# Get:61 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusparse-dev-11-8 11.7.5.86-1 [116 MB]
# Get:62 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnpp-dev-11-8 11.8.0.86-1 [100 MB]
# Get:63 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjpeg-dev-11-8 11.9.0.86-1 [1,536 kB]
# Get:64 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-libraries-dev-11-8 11.8.0-1 [2,554 B]
# Get:65 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-11-8 11.8.86-1 [119 MB]
# Get:66 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nsight-compute-2022.3.0 2022.3.0.22-1 [580 MB]
# Get:67 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-compute-11-8 11.8.0-1 [3,790 B]
# Get:68 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nsight-systems-2022.4.2 2022.4.2.50-32196742v0 [286 MB]
# Get:69 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-systems-11-8 11.8.0-1 [3,310 B]
# Get:70 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvml-dev-11-8 11.8.86-1 [81.4 kB]
# Get:71 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvvp-11-8 11.8.87-1 [114 MB]
# Get:72 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-visual-tools-11-8 11.8.0-1 [2,870 B]
# Get:73 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  gds-tools-11-8 1.4.0.31-1 [38.7 MB]
# Get:74 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-tools-11-8 11.8.0-1 [2,390 B]
# Get:75 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-toolkit-11-8 11.8.0-1 [3,374 B]
# Fetched 2,715 MB in 50s (54.0 MB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package cuda-cccl-11-8.
# (Reading database ... 124574 files and directories currently installed.)
# Preparing to unpack .../00-cuda-cccl-11-8_11.8.89-1_amd64.deb ...
# Unpacking cuda-cccl-11-8 (11.8.89-1) ...
# Selecting previously unselected package cuda-cupti-11-8.
# Preparing to unpack .../01-cuda-cupti-11-8_11.8.87-1_amd64.deb ...
# Unpacking cuda-cupti-11-8 (11.8.87-1) ...
# Selecting previously unselected package cuda-cupti-dev-11-8.
# Preparing to unpack .../02-cuda-cupti-dev-11-8_11.8.87-1_amd64.deb ...
# Unpacking cuda-cupti-dev-11-8 (11.8.87-1) ...
# Selecting previously unselected package cuda-nvdisasm-11-8.
# Preparing to unpack .../03-cuda-nvdisasm-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-nvdisasm-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-cuobjdump-11-8.
# Preparing to unpack .../04-cuda-cuobjdump-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-cuobjdump-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-gdb-11-8.
# Preparing to unpack .../05-cuda-gdb-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-gdb-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-memcheck-11-8.
# Preparing to unpack .../06-cuda-memcheck-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-memcheck-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-nvprof-11-8.
# Preparing to unpack .../07-cuda-nvprof-11-8_11.8.87-1_amd64.deb ...
# Unpacking cuda-nvprof-11-8 (11.8.87-1) ...
# Selecting previously unselected package cuda-nvtx-11-8.
# Preparing to unpack .../08-cuda-nvtx-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-nvtx-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-sanitizer-11-8.
# Preparing to unpack .../09-cuda-sanitizer-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-sanitizer-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-command-line-tools-11-8.
# Preparing to unpack .../10-cuda-command-line-tools-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-command-line-tools-11-8 (11.8.0-1) ...
# Selecting previously unselected package cuda-cuxxfilt-11-8.
# Preparing to unpack .../11-cuda-cuxxfilt-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-cuxxfilt-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-toolkit-11-config-common.
# Preparing to unpack .../12-cuda-toolkit-11-config-common_11.8.89-1_all.deb ...
# Unpacking cuda-toolkit-11-config-common (11.8.89-1) ...
# Selecting previously unselected package cuda-toolkit-11-8-config-common.
# Preparing to unpack .../13-cuda-toolkit-11-8-config-common_11.8.89-1_all.deb ...
# Unpacking cuda-toolkit-11-8-config-common (11.8.89-1) ...
# Selecting previously unselected package cuda-cudart-11-8.
# Preparing to unpack .../14-cuda-cudart-11-8_11.8.89-1_amd64.deb ...
# Unpacking cuda-cudart-11-8 (11.8.89-1) ...
# Selecting previously unselected package cuda-driver-dev-11-8.
# Preparing to unpack .../15-cuda-driver-dev-11-8_11.8.89-1_amd64.deb ...
# Unpacking cuda-driver-dev-11-8 (11.8.89-1) ...
# Selecting previously unselected package cuda-cudart-dev-11-8.
# Preparing to unpack .../16-cuda-cudart-dev-11-8_11.8.89-1_amd64.deb ...
# Unpacking cuda-cudart-dev-11-8 (11.8.89-1) ...
# Selecting previously unselected package cuda-nvcc-11-8.
# Preparing to unpack .../17-cuda-nvcc-11-8_11.8.89-1_amd64.deb ...
# Unpacking cuda-nvcc-11-8 (11.8.89-1) ...
# Selecting previously unselected package cuda-nvprune-11-8.
# Preparing to unpack .../18-cuda-nvprune-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-nvprune-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-compiler-11-8.
# Preparing to unpack .../19-cuda-compiler-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-compiler-11-8 (11.8.0-1) ...
# Selecting previously unselected package cuda-documentation-11-8.
# Preparing to unpack .../20-cuda-documentation-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-documentation-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-nvrtc-11-8.
# Preparing to unpack .../21-cuda-nvrtc-11-8_11.8.89-1_amd64.deb ...
# Unpacking cuda-nvrtc-11-8 (11.8.89-1) ...
# Selecting previously unselected package libcublas-11-8.
# Preparing to unpack .../22-libcublas-11-8_11.11.3.6-1_amd64.deb ...
# Unpacking libcublas-11-8 (11.11.3.6-1) ...
# Selecting previously unselected package libcufft-11-8.
# Preparing to unpack .../23-libcufft-11-8_10.9.0.58-1_amd64.deb ...
# Unpacking libcufft-11-8 (10.9.0.58-1) ...
# Selecting previously unselected package libcufile-11-8.
# Preparing to unpack .../24-libcufile-11-8_1.4.0.31-1_amd64.deb ...
# Unpacking libcufile-11-8 (1.4.0.31-1) ...
# Selecting previously unselected package libcurand-11-8.
# Preparing to unpack .../25-libcurand-11-8_10.3.0.86-1_amd64.deb ...
# Unpacking libcurand-11-8 (10.3.0.86-1) ...
# Selecting previously unselected package libcusolver-11-8.
# Preparing to unpack .../26-libcusolver-11-8_11.4.1.48-1_amd64.deb ...
# Unpacking libcusolver-11-8 (11.4.1.48-1) ...
# Selecting previously unselected package libcusparse-11-8.
# Preparing to unpack .../27-libcusparse-11-8_11.7.5.86-1_amd64.deb ...
# Unpacking libcusparse-11-8 (11.7.5.86-1) ...
# Selecting previously unselected package libnpp-11-8.
# Preparing to unpack .../28-libnpp-11-8_11.8.0.86-1_amd64.deb ...
# Unpacking libnpp-11-8 (11.8.0.86-1) ...
# Selecting previously unselected package libnvjpeg-11-8.
# Preparing to unpack .../29-libnvjpeg-11-8_11.9.0.86-1_amd64.deb ...
# Unpacking libnvjpeg-11-8 (11.9.0.86-1) ...
# Selecting previously unselected package cuda-libraries-11-8.
# Preparing to unpack .../30-cuda-libraries-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-libraries-11-8 (11.8.0-1) ...
# Selecting previously unselected package cuda-profiler-api-11-8.
# Preparing to unpack .../31-cuda-profiler-api-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-profiler-api-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-nvrtc-dev-11-8.
# Preparing to unpack .../32-cuda-nvrtc-dev-11-8_11.8.89-1_amd64.deb ...
# Unpacking cuda-nvrtc-dev-11-8 (11.8.89-1) ...
# Selecting previously unselected package libcublas-dev-11-8.
# Preparing to unpack .../33-libcublas-dev-11-8_11.11.3.6-1_amd64.deb ...
# Unpacking libcublas-dev-11-8 (11.11.3.6-1) ...
# Selecting previously unselected package libcufft-dev-11-8.
# Preparing to unpack .../34-libcufft-dev-11-8_10.9.0.58-1_amd64.deb ...
# Unpacking libcufft-dev-11-8 (10.9.0.58-1) ...
# Selecting previously unselected package libcufile-dev-11-8.
# Preparing to unpack .../35-libcufile-dev-11-8_1.4.0.31-1_amd64.deb ...
# Unpacking libcufile-dev-11-8 (1.4.0.31-1) ...
# Selecting previously unselected package libcurand-dev-11-8.
# Preparing to unpack .../36-libcurand-dev-11-8_10.3.0.86-1_amd64.deb ...
# Unpacking libcurand-dev-11-8 (10.3.0.86-1) ...
# Selecting previously unselected package libcusolver-dev-11-8.
# Preparing to unpack .../37-libcusolver-dev-11-8_11.4.1.48-1_amd64.deb ...
# Unpacking libcusolver-dev-11-8 (11.4.1.48-1) ...
# Selecting previously unselected package libcusparse-dev-11-8.
# Preparing to unpack .../38-libcusparse-dev-11-8_11.7.5.86-1_amd64.deb ...
# Unpacking libcusparse-dev-11-8 (11.7.5.86-1) ...
# Selecting previously unselected package libnpp-dev-11-8.
# Preparing to unpack .../39-libnpp-dev-11-8_11.8.0.86-1_amd64.deb ...
# Unpacking libnpp-dev-11-8 (11.8.0.86-1) ...
# Selecting previously unselected package libnvjpeg-dev-11-8.
# Preparing to unpack .../40-libnvjpeg-dev-11-8_11.9.0.86-1_amd64.deb ...
# Unpacking libnvjpeg-dev-11-8 (11.9.0.86-1) ...
# Selecting previously unselected package cuda-libraries-dev-11-8.
# Preparing to unpack .../41-cuda-libraries-dev-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-libraries-dev-11-8 (11.8.0-1) ...
# Selecting previously unselected package default-jre-headless.
# Preparing to unpack .../42-default-jre-headless_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre-headless (2:1.11-72build2) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../43-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../44-openjdk-11-jre_11.0.25+9-1ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.25+9-1ubuntu1~22.04) ...
# Selecting previously unselected package default-jre.
# Preparing to unpack .../45-default-jre_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre (2:1.11-72build2) ...
# Selecting previously unselected package cuda-nsight-11-8.
# Preparing to unpack .../46-cuda-nsight-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-nsight-11-8 (11.8.86-1) ...
# Selecting previously unselected package nsight-compute-2022.3.0.
# Preparing to unpack .../47-nsight-compute-2022.3.0_2022.3.0.22-1_amd64.deb ...
# Unpacking nsight-compute-2022.3.0 (2022.3.0.22-1) ...
# Selecting previously unselected package cuda-nsight-compute-11-8.
# Preparing to unpack .../48-cuda-nsight-compute-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-nsight-compute-11-8 (11.8.0-1) ...
# Selecting previously unselected package libtinfo5:amd64.
# Preparing to unpack .../49-libtinfo5_6.3-2ubuntu0.1_amd64.deb ...
# Unpacking libtinfo5:amd64 (6.3-2ubuntu0.1) ...
# Selecting previously unselected package libxcb-xinerama0:amd64.
# Preparing to unpack .../50-libxcb-xinerama0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-icccm4:amd64.
# Preparing to unpack .../51-libxcb-icccm4_0.4.1-1.1build2_amd64.deb ...
# Unpacking libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Selecting previously unselected package libxcb-util1:amd64.
# Preparing to unpack .../52-libxcb-util1_0.4.0-1build2_amd64.deb ...
# Unpacking libxcb-util1:amd64 (0.4.0-1build2) ...
# Selecting previously unselected package libxcb-image0:amd64.
# Preparing to unpack .../53-libxcb-image0_0.4.0-2_amd64.deb ...
# Unpacking libxcb-image0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libxcb-keysyms1:amd64.
# Preparing to unpack .../54-libxcb-keysyms1_0.4.0-1build3_amd64.deb ...
# Unpacking libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Selecting previously unselected package libxcb-render-util0:amd64.
# Preparing to unpack .../55-libxcb-render-util0_0.3.9-1build3_amd64.deb ...
# Unpacking libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Selecting previously unselected package libxcb-xkb1:amd64.
# Preparing to unpack .../56-libxcb-xkb1_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxkbcommon-x11-0:amd64.
# Preparing to unpack .../57-libxkbcommon-x11-0_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Selecting previously unselected package libxcb-xinput0:amd64.
# Preparing to unpack .../58-libxcb-xinput0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package nsight-systems-2022.4.2.
# Preparing to unpack .../59-nsight-systems-2022.4.2_2022.4.2.50-32196742v0_amd64.deb ...
# Unpacking nsight-systems-2022.4.2 (2022.4.2.50-32196742v0) ...
# Selecting previously unselected package cuda-nsight-systems-11-8.
# Preparing to unpack .../60-cuda-nsight-systems-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-nsight-systems-11-8 (11.8.0-1) ...
# Selecting previously unselected package cuda-nvml-dev-11-8.
# Preparing to unpack .../61-cuda-nvml-dev-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-nvml-dev-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-nvvp-11-8.
# Preparing to unpack .../62-cuda-nvvp-11-8_11.8.87-1_amd64.deb ...
# Unpacking cuda-nvvp-11-8 (11.8.87-1) ...
# Selecting previously unselected package cuda-visual-tools-11-8.
# Preparing to unpack .../63-cuda-visual-tools-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-visual-tools-11-8 (11.8.0-1) ...
# Selecting previously unselected package gds-tools-11-8.
# Preparing to unpack .../64-gds-tools-11-8_1.4.0.31-1_amd64.deb ...
# Unpacking gds-tools-11-8 (1.4.0.31-1) ...
# Selecting previously unselected package cuda-tools-11-8.
# Preparing to unpack .../65-cuda-tools-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-tools-11-8 (11.8.0-1) ...
# Selecting previously unselected package cuda-toolkit-11-8.
# Preparing to unpack .../66-cuda-toolkit-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-toolkit-11-8 (11.8.0-1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../67-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../68-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../69-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../70-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../71-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../72-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../73-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../74-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up cuda-nvml-dev-11-8 (11.8.86-1) ...
# Setting up default-jre-headless (2:1.11-72build2) ...
# Setting up cuda-toolkit-11-config-common (11.8.89-1) ...
# Setting up libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Setting up cuda-cccl-11-8 (11.8.89-1) ...
# Setting up cuda-cuobjdump-11-8 (11.8.86-1) ...
# Setting up cuda-nvrtc-11-8 (11.8.89-1) ...
# Setting up cuda-sanitizer-11-8 (11.8.86-1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up cuda-cupti-11-8 (11.8.87-1) ...
# Setting up libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Setting up openjdk-11-jre:amd64 (11.0.25+9-1ubuntu1~22.04) ...
# Setting up cuda-nvdisasm-11-8 (11.8.86-1) ...
# Setting up libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Setting up default-jre (2:1.11-72build2) ...
# Setting up cuda-cuxxfilt-11-8 (11.8.86-1) ...
# Setting up libxcb-util1:amd64 (0.4.0-1build2) ...
# Setting up libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Setting up libxcb-image0:amd64 (0.4.0-2) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Setting up cuda-nvvp-11-8 (11.8.87-1) ...
# Setting up cuda-nvtx-11-8 (11.8.86-1) ...
# Setting up cuda-gdb-11-8 (11.8.86-1) ...
# Setting up cuda-toolkit-11-8-config-common (11.8.89-1) ...
# Setting alternatives
# update-alternatives: using /usr/local/cuda-11.8 to provide /usr/local/cuda-11 (cuda-11) in auto mode
# Setting up libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Setting up libcusolver-11-8 (11.4.1.48-1) ...
# Setting up cuda-nvrtc-dev-11-8 (11.8.89-1) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up cuda-driver-dev-11-8 (11.8.89-1) ...
# Setting up cuda-memcheck-11-8 (11.8.86-1) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up gds-tools-11-8 (1.4.0.31-1) ...
# Setting up cuda-nsight-11-8 (11.8.86-1) ...
# Setting up cuda-profiler-api-11-8 (11.8.86-1) ...
# Setting up cuda-documentation-11-8 (11.8.86-1) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libtinfo5:amd64 (6.3-2ubuntu0.1) ...
# Setting up cuda-nvprune-11-8 (11.8.86-1) ...
# Setting up cuda-cudart-11-8 (11.8.89-1) ...
# Setting up libnvjpeg-11-8 (11.9.0.86-1) ...
# Setting up cuda-nvprof-11-8 (11.8.87-1) ...
# Setting up nsight-compute-2022.3.0 (2022.3.0.22-1) ...
# Setting up nsight-systems-2022.4.2 (2022.4.2.50-32196742v0) ...
# update-alternatives: using /opt/nvidia/nsight-systems/2022.4.2/target-linux-x64/nsys to provide /usr/local/bin/nsys (nsys) in auto mode
# update-alternatives: using /opt/nvidia/nsight-systems/2022.4.2/host-linux-x64/nsys-ui to provide /usr/local/bin/nsys-ui (nsys-ui) in auto mode
# Setting up libcusparse-11-8 (11.7.5.86-1) ...
# Setting up libcufft-11-8 (10.9.0.58-1) ...
# Setting up cuda-cupti-dev-11-8 (11.8.87-1) ...
# Setting up libcufft-dev-11-8 (10.9.0.58-1) ...
# Setting up cuda-cudart-dev-11-8 (11.8.89-1) ...
# Setting up libnpp-11-8 (11.8.0.86-1) ...
# Setting up libcusolver-dev-11-8 (11.4.1.48-1) ...
# Setting up cuda-nsight-systems-11-8 (11.8.0-1) ...
# Setting up cuda-command-line-tools-11-8 (11.8.0-1) ...
# Setting up libcusparse-dev-11-8 (11.7.5.86-1) ...
# Setting up libcurand-11-8 (10.3.0.86-1) ...
# Setting up libcufile-11-8 (1.4.0.31-1) ...
# Setting alternatives
# Setting up libcublas-11-8 (11.11.3.6-1) ...
# Setting up libnpp-dev-11-8 (11.8.0.86-1) ...
# Setting up cuda-libraries-11-8 (11.8.0-1) ...
# Setting up cuda-nsight-compute-11-8 (11.8.0-1) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up libnvjpeg-dev-11-8 (11.9.0.86-1) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up cuda-nvcc-11-8 (11.8.89-1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up libcublas-dev-11-8 (11.11.3.6-1) ...
# Setting up libcurand-dev-11-8 (10.3.0.86-1) ...
# Setting up libcufile-dev-11-8 (1.4.0.31-1) ...
# Setting up cuda-compiler-11-8 (11.8.0-1) ...
# Setting up cuda-libraries-dev-11-8 (11.8.0-1) ...
# Setting up cuda-visual-tools-11-8 (11.8.0-1) ...
# Setting up cuda-tools-11-8 (11.8.0-1) ...
# Setting up cuda-toolkit-11-8 (11.8.0-1) ...
# Setting alternatives
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %% [markdown]
# Installing & preparing requirements

# %%
# !git clone https://github.com/HMK71/roop-un.git
# %cd roop-un
# !mv config_colab.yaml config.yaml
# !pip install -r requirements.txt
# Out:
# fatal: destination path 'roop-un' already exists and is not an empty directory.
# /content/roop-un
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# Ignoring torch: markers 'sys_platform == "darwin"' don't match your environment
# Ignoring torchvision: markers 'sys_platform == "darwin"' don't match your environment
# Ignoring onnxruntime: markers 'sys_platform == "darwin" and platform_machine != "arm64"' don't match your environment
# Ignoring onnxruntime-silicon: markers 'sys_platform == "darwin" and platform_machine == "arm64"' don't match your environment
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (1.26.4)
# Collecting gradio==4.42.0 (from -r requirements.txt (line 4))
#   Downloading gradio-4.42.0-py3-none-any.whl.metadata (15 kB)
# Collecting fastapi<0.113.0 (from -r requirements.txt (line 5))
#   Downloading fastapi-0.112.4-py3-none-any.whl.metadata (27 kB)
# Collecting opencv-python==4.9.0.80 (from -r requirements.txt (line 6))
#   Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting onnx==1.16.0 (from -r requirements.txt (line 7))
#   Downloading onnx-1.16.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Collecting insightface==0.7.3 (from -r requirements.txt (line 8))
#   Downloading insightface-0.7.3.tar.gz (439 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.5/439.5 kB 13.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting psutil==5.9.6 (from -r requirements.txt (line 9))
#   Downloading psutil-5.9.6-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Collecting torch==2.1.2+cu118 (from -r requirements.txt (line 10))
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.1.2%2Bcu118-cp311-cp311-linux_x86_64.whl (2325.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 674.4 kB/s eta 0:00:00
# Collecting torchvision==0.16.2+cu118 (from -r requirements.txt (line 12))
#   Downloading https://download.pytorch.org/whl/cu118/torchvision-0.16.2%2Bcu118-cp311-cp311-linux_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 103.5 MB/s eta 0:00:00
# Collecting onnxruntime-gpu==1.17.1 (from -r requirements.txt (line 16))
#   Downloading onnxruntime_gpu-1.17.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.3 kB)
# Collecting tqdm==4.66.4 (from -r requirements.txt (line 17))
#   Downloading tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 5.8 MB/s eta 0:00:00
# Collecting ftfy (from -r requirements.txt (line 18))
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 19)) (2024.11.6)
# Collecting pyvirtualcam (from -r requirements.txt (line 20))
#   Downloading pyvirtualcam-0.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio==4.42.0->-r requirements.txt (line 4))
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio==4.42.0->-r requirements.txt (line 4)) (3.7.1)
# Collecting ffmpy (from gradio==4.42.0->-r requirements.txt (line 4))
#   Downloading ffmpy-0.5.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==1.3.0 (from gradio==4.42.0->-r requirements.txt (line 4))
#   Downloading gradio_client-1.3.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.11/dist-packages (from gradio==4.42.0->-r requirements.txt (line 4)) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /usr/local/lib/python3.11/dist-packages (from gradio==4.42.0->-r requirements.txt (line 4)) (0.27.1)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.11/dist-packages (from gradio==4.42.0->-r requirements.txt (line 4)) (6.5.2)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.11/dist-packages (from gradio==4.42.0->-r requirements.txt (line 4)) (3.1.5)
# Collecting markupsafe~=2.0 (from gradio==4.42.0->-r requirements.txt (line 4))
#   Downloading https://download.pytorch.org/whl/MarkupSafe-2.1.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio==4.42.0->-r requirements.txt (line 4)) (3.10.0)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio==4.42.0->-r requirements.txt (line 4)) (3.10.15)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from gradio==4.42.0->-r requirements.txt (line 4)) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.11/dist-packages (from gradio==4.42.0->-r requirements.txt (line 4)) (2.2.2)
# Collecting pillow<11.0,>=8.0 (from gradio==4.42.0->-r requirements.txt (line 4))
#   Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio==4.42.0->-r requirements.txt (line 4)) (2.10.5)
# Collecting pydub (from gradio==4.42.0->-r requirements.txt (line 4))
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.9 (from gradio==4.42.0->-r requirements.txt (line 4))
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.11/dist-packages (from gradio==4.42.0->-r requirements.txt (line 4)) (6.0.2)
# Collecting ruff>=0.2.2 (from gradio==4.42.0->-r requirements.txt (line 4))
#   Downloading ruff-0.9.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting semantic-version~=2.0 (from gradio==4.42.0->-r requirements.txt (line 4))
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tomlkit==0.12.0 (from gradio==4.42.0->-r requirements.txt (line 4))
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from gradio==4.42.0->-r requirements.txt (line 4)) (0.15.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.11/dist-packages (from gradio==4.42.0->-r requirements.txt (line 4)) (4.12.2)
# Requirement already satisfied: urllib3~=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio==4.42.0->-r requirements.txt (line 4)) (2.3.0)
# Collecting uvicorn>=0.14.0 (from gradio==4.42.0->-r requirements.txt (line 4))
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from onnx==1.16.0->-r requirements.txt (line 7)) (4.25.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from insightface==0.7.3->-r requirements.txt (line 8)) (2.32.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from insightface==0.7.3->-r requirements.txt (line 8)) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from insightface==0.7.3->-r requirements.txt (line 8)) (1.6.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from insightface==0.7.3->-r requirements.txt (line 8)) (0.25.0)
# Requirement already satisfied: easydict in /usr/local/lib/python3.11/dist-packages (from insightface==0.7.3->-r requirements.txt (line 8)) (1.13)
# Requirement already satisfied: cython in /usr/local/lib/python3.11/dist-packages (from insightface==0.7.3->-r requirements.txt (line 8)) (3.0.11)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.11/dist-packages (from insightface==0.7.3->-r requirements.txt (line 8)) (1.4.20)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.11/dist-packages (from insightface==0.7.3->-r requirements.txt (line 8)) (3.12.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.1.2+cu118->-r requirements.txt (line 10)) (3.17.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.1.2+cu118->-r requirements.txt (line 10)) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.1.2+cu118->-r requirements.txt (line 10)) (3.4.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.1.2+cu118->-r requirements.txt (line 10)) (2024.10.0)
# Collecting triton==2.1.0 (from torch==2.1.2+cu118->-r requirements.txt (line 10))
#   Downloading https://download.pytorch.org/whl/triton-2.1.0-0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 10.1 MB/s eta 0:00:00
# Collecting coloredlogs (from onnxruntime-gpu==1.17.1->-r requirements.txt (line 16))
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime-gpu==1.17.1->-r requirements.txt (line 16)) (25.1.21)
# Collecting websockets<13.0,>=10.0 (from gradio-client==1.3.0->gradio==4.42.0->-r requirements.txt (line 4))
#   Downloading websockets-12.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting starlette<0.39.0,>=0.37.2 (from fastapi<0.113.0->-r requirements.txt (line 5))
#   Downloading starlette-0.38.6-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy->-r requirements.txt (line 18)) (0.2.13)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio==4.42.0->-r requirements.txt (line 4)) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio==4.42.0->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio==4.42.0->-r requirements.txt (line 4)) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio==4.42.0->-r requirements.txt (line 4)) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio==4.42.0->-r requirements.txt (line 4)) (0.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->gradio==4.42.0->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->gradio==4.42.0->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->gradio==4.42.0->-r requirements.txt (line 4)) (4.55.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->gradio==4.42.0->-r requirements.txt (line 4)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->gradio==4.42.0->-r requirements.txt (line 4)) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->gradio==4.42.0->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio==4.42.0->-r requirements.txt (line 4)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio==4.42.0->-r requirements.txt (line 4)) (2025.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->gradio==4.42.0->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->gradio==4.42.0->-r requirements.txt (line 4)) (2.27.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio==4.42.0->-r requirements.txt (line 4)) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio==4.42.0->-r requirements.txt (line 4)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio==4.42.0->-r requirements.txt (line 4)) (13.9.4)
# Requirement already satisfied: albucore==0.0.19 in /usr/local/lib/python3.11/dist-packages (from albumentations->insightface==0.7.3->-r requirements.txt (line 8)) (0.0.19)
# Requirement already satisfied: eval-type-backport in /usr/local/lib/python3.11/dist-packages (from albumentations->insightface==0.7.3->-r requirements.txt (line 8)) (0.2.2)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.11/dist-packages (from albumentations->insightface==0.7.3->-r requirements.txt (line 8)) (4.11.0.86)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.19->albumentations->insightface==0.7.3->-r requirements.txt (line 8)) (3.11.3)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime-gpu==1.17.1->-r requirements.txt (line 16))
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->insightface==0.7.3->-r requirements.txt (line 8)) (3.4.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->insightface==0.7.3->-r requirements.txt (line 8)) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->insightface==0.7.3->-r requirements.txt (line 8)) (2025.1.10)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->insightface==0.7.3->-r requirements.txt (line 8)) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->insightface==0.7.3->-r requirements.txt (line 8)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->insightface==0.7.3->-r requirements.txt (line 8)) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.1.2+cu118->-r requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio==4.42.0->-r requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==4.42.0->-r requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==4.42.0->-r requirements.txt (line 4)) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio==4.42.0->-r requirements.txt (line 4)) (0.1.2)
# Downloading gradio-4.42.0-py3-none-any.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 7.8 MB/s eta 0:00:00
# Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 11.3 MB/s eta 0:00:00
# Downloading onnx-1.16.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 94.3 MB/s eta 0:00:00
# Downloading psutil-5.9.6-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (283 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.6/283.6 kB 28.0 MB/s eta 0:00:00
# Downloading onnxruntime_gpu-1.17.1-cp311-cp311-manylinux_2_28_x86_64.whl (192.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.1/192.1 MB 5.2 MB/s eta 0:00:00
# Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 7.4 MB/s eta 0:00:00
# Downloading gradio_client-1.3.0-py3-none-any.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.7/318.7 kB 29.7 MB/s eta 0:00:00
# Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Downloading fastapi-0.112.4-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 kB 6.0 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.2 MB/s eta 0:00:00
# Downloading pyvirtualcam-0.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.2/149.2 kB 16.1 MB/s eta 0:00:00
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 86.4 MB/s eta 0:00:00
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading ruff-0.9.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 74.3 MB/s eta 0:00:00
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.38.6-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 7.6 MB/s eta 0:00:00
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 6.8 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.0 MB/s eta 0:00:00
# Downloading ffmpy-0.5.0-py3-none-any.whl (6.0 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 9.8 MB/s eta 0:00:00
# Downloading websockets-12.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.9/130.9 kB 11.3 MB/s eta 0:00:00
# Building wheels for collected packages: insightface
#   Building wheel for insightface (pyproject.toml) ... done
#   Created wheel for insightface: filename=insightface-0.7.3-cp311-cp311-linux_x86_64.whl size=1064897 sha256=b6c6ed008f3c93f4bd435694eacc326fedae22e1765242cc684d1bfd26140f09
#   Stored in directory: /root/.cache/pip/wheels/27/d8/22/f52d858d16cd06e7b2e6aad34a1777dcfaf000be833bbf8146
# Successfully built insightface
# Installing collected packages: pydub, websockets, uvicorn, triton, tqdm, tomlkit, semantic-version, ruff, pyvirtualcam, python-multipart, psutil, pillow, opencv-python, onnx, markupsafe, humanfriendly, ftfy, ffmpy, aiofiles, starlette, coloredlogs, torch, onnxruntime-gpu, gradio-client, fastapi, torchvision, insightface, gradio
#   Attempting uninstall: websockets
#     Found existing installation: websockets 14.2
#     Uninstalling websockets-14.2:
#       Successfully uninstalled websockets-14.2
#   Attempting uninstall: triton
#     Found existing installation: triton 3.1.0
#     Uninstalling triton-3.1.0:
#       Successfully uninstalled triton-3.1.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.10.0.84
#     Uninstalling opencv-python-4.10.0.84:
#       Successfully uninstalled opencv-python-4.10.0.84
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1+cu121
#     Uninstalling torch-2.5.1+cu121:
#       Successfully uninstalled torch-2.5.1+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.1+cu121
#     Uninstalling torchvision-0.20.1+cu121:
#       Successfully uninstalled torchvision-0.20.1+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 2.1.2+cu118 which is incompatible.
# google-genai 0.3.0 requires websockets<15.0dev,>=13.0, but you have websockets 12.0 which is incompatible.
# Successfully installed aiofiles-23.2.1 coloredlogs-15.0.1 fastapi-0.112.4 ffmpy-0.5.0 ftfy-6.3.1 gradio-4.42.0 gradio-client-1.3.0 humanfriendly-10.0 insightface-0.7.3 markupsafe-2.1.5 onnx-1.16.0 onnxruntime-gpu-1.17.1 opencv-python-4.9.0.80 pillow-10.4.0 psutil-5.9.6 pydub-0.25.1 python-multipart-0.0.20 pyvirtualcam-0.12.1 ruff-0.9.3 semantic-version-2.10.0 starlette-0.38.6 tomlkit-0.12.0 torch-2.1.2+cu118 torchvision-0.16.2+cu118 tqdm-4.66.4 triton-2.1.0 uvicorn-0.34.0 websockets-12.0

# %% [markdown]
# Running roop-unleashed with default config

# %%
# !python run.py
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.1 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Number of CUDA devices: 1 Currently used Id: 0 Device Name: Tesla T4
# Using provider [('CUDAExecutionProvider', {'device_id': 0})] - Device:cuda
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://bb5ea6e2d9cae7d574.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'prefer_nhwc': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_max_tuning_duration_ms': '0', 'use_ep_level_unified_stream': '0', 'tunable_op_enable': '0', 'enable_cuda_graph': '0', 'cudnn_conv_use_max_workspace': '1', 'do_copy_in_default_stream': '1', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'gpu_external_empty_cache': '0', 'gpu_external_free': '0', 'tunable_op_tuning_enable': '0', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_external_alloc': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'has_user_compute_stream': '0', 'gpu_mem_limit': '18446744073709551615', 'device_id': '0'}}
# find model: /content/roop-un/models/buffalo_l/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'prefer_nhwc': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_max_tuning_duration_ms': '0', 'use_ep_level_unified_stream': '0', 'tunable_op_enable': '0', 'enable_cuda_graph': '0', 'cudnn_conv_use_max_workspace': '1', 'do_copy_in_default_stream': '1', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'gpu_external_empty_cache': '0', 'gpu_external_free': '0', 'tunable_op_tuning_enable': '0', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_external_alloc': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'has_user_compute_stream': '0', 'gpu_mem_limit': '18446744073709551615', 'device_id': '0'}}
# find model: /content/roop-un/models/buffalo_l/2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'prefer_nhwc': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_max_tuning_duration_ms': '0', 'use_ep_level_unified_stream': '0', 'tunable_op_enable': '0', 'enable_cuda_graph': '0', 'cudnn_conv_use_max_workspace': '1', 'do_copy_in_default_stream': '1', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'gpu_external_empty_cache': '0', 'gpu_external_free': '0', 'tunable_op_tuning_enable': '0', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_external_alloc': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'has_user_compute_stream': '0', 'gpu_mem_limit': '18446744073709551615', 'device_id': '0'}}
# find model: /content/roop-un/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'prefer_nhwc': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_max_tuning_duration_ms': '0', 'use_ep_level_unified_stream': '0', 'tunable_op_enable': '0', 'enable_cuda_graph': '0', 'cudnn_conv_use_max_workspace': '1', 'do_copy_in_default_stream': '1', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'gpu_external_empty_cache': '0', 'gpu_external_free': '0', 'tunable_op_tuning_enable': '0', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_external_alloc': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'has_user_compute_stream': '0', 'gpu_mem_limit': '18446744073709551615', 'device_id': '0'}}
# find model: /content/roop-un/models/buffalo_l/genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'prefer_nhwc': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_max_tuning_duration_ms': '0', 'use_ep_level_unified_stream': '0', 'tunable_op_enable': '0', 'enable_cuda_graph': '0', 'cudnn_conv_use_max_workspace': '1', 'do_copy_in_default_stream': '1', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'gpu_external_empty_cache': '0', 'gpu_external_free': '0', 'tunable_op_tuning_enable': '0', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_external_alloc': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'has_user_compute_stream': '0', 'gpu_mem_limit': '18446744073709551615', 'device_id': '0'}}
# find model: /content/roop-un/models/buffalo_l/w600k_r50.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (640, 640)
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'prefer_nhwc': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_max_tuning_duration_ms': '0', 'use_ep_level_unified_stream': '0', 'tunable_op_enable': '0', 'enable_cuda_graph': '0', 'cudnn_conv_use_max_workspace': '1', 'do_copy_in_default_stream': '1', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'gpu_external_empty_cache': '0', 'gpu_external_free': '0', 'tunable_op_tuning_enable': '0', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_external_alloc': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'has_user_compute_stream': '0', 'gpu_mem_limit': '18446744073709551615', 'device_id': '0'}}
# find model: /content/roop-un/models/buffalo_l/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'prefer_nhwc': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_max_tuning_duration_ms': '0', 'use_ep_level_unified_stream': '0', 'tunable_op_enable': '0', 'enable_cuda_graph': '0', 'cudnn_conv_use_max_workspace': '1', 'do_copy_in_default_stream': '1', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'gpu_external_empty_cache': '0', 'gpu_external_free': '0', 'tunable_op_tuning_enable': '0', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_external_alloc': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'has_user_compute_stream': '0', 'gpu_mem_limit': '18446744073709551615', 'device_id': '0'}}
# find model: /content/roop-un/models/buffalo_l/2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'prefer_nhwc': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_max_tuning_duration_ms': '0', 'use_ep_level_unified_stream': '0', 'tunable_op_enable': '0', 'enable_cuda_graph': '0', 'cudnn_conv_use_max_workspace': '1', 'do_copy_in_default_stream': '1', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'gpu_external_empty_cache': '0', 'gpu_external_free': '0', 'tunable_op_tuning_enable': '0', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_external_alloc': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'has_user_compute_stream': '0', 'gpu_mem_limit': '18446744073709551615', 'device_id': '0'}}
# find model: /content/roop-un/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'prefer_nhwc': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_max_tuning_duration_ms': '0', 'use_ep_level_unified_stream': '0', 'tunable_op_enable': '0', 'enable_cuda_graph': '0', 'cudnn_conv_use_max_workspace': '1', 'do_copy_in_default_stream': '1', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'gpu_external_empty_cache': '0', 'gpu_external_free': '0', 'tunable_op_tuning_enable': '0', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_external_alloc': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'has_user_compute_stream': '0', 'gpu_mem_limit': '18446744073709551615', 'device_id': '0'}}
# model ignore: /content/roop-un/models/buffalo_l/genderage.onnx genderage
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'prefer_nhwc': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_max_tuning_duration_ms': '0', 'use_ep_level_unified_stream': '0', 'tunable_op_enable': '0', 'enable_cuda_graph': '0', 'cudnn_conv_use_max_workspace': '1', 'do_copy_in_default_stream': '1', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'gpu_external_empty_cache': '0', 'gpu_external_free': '0', 'tunable_op_tuning_enable': '0', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_external_alloc': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'has_user_compute_stream': '0', 'gpu_mem_limit': '18446744073709551615', 'device_id': '0'}}
# find model: /content/roop-un/models/buffalo_l/w600k_r50.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (640, 640)
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/uvicorn/protocols/http/h11_impl.py", line 403, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/uvicorn/middleware/proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/fastapi/applications.py", line 1054, in __call__
#     await super().__call__(scope, receive, send)
#   File "/usr/local/lib/python3.11/dist-packages/starlette/applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/usr/local/lib/python3.11/dist-packages/starlette/middleware/errors.py", line 187, in __call__
#     raise exc
#   File "/usr/local/lib/python3.11/dist-packages/starlette/middleware/errors.py", line 165, in __call__
#     await self.app(scope, receive, _send)
#   File "/usr/local/lib/python3.11/dist-packages/gradio/route_utils.py", line 766, in __call__
#     await self.simple_response(scope, receive, send, request_headers=headers)
#   File "/usr/local/lib/python3.11/dist-packages/gradio/route_utils.py", line 782, in simple_response
#     await self.app(scope, receive, send)
#   File "/usr/local/lib/python3.11/dist-packages/starlette/middleware/exceptions.py", line 62, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "/usr/local/lib/python3.11/dist-packages/starlette/_exception_handler.py", line 62, in wrapped_app
#     raise exc
#   File "/usr/local/lib/python3.11/dist-packages/starlette/_exception_handler.py", line 51, in wrapped_app
#     await app(scope, receive, sender)
#   File "/usr/local/lib/python3.11/dist-packages/starlette/routing.py", line 715, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/usr/local/lib/python3.11/dist-packages/starlette/routing.py", line 735, in app
#     await route.handle(scope, receive, send)
#   File "/usr/local/lib/python3.11/dist-packages/starlette/routing.py", line 288, in handle
#     await self.app(scope, receive, send)
#   File "/usr/local/lib/python3.11/dist-packages/starlette/routing.py", line 76, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "/usr/local/lib/python3.11/dist-packages/starlette/_exception_handler.py", line 62, in wrapped_app
#     raise exc
#   File "/usr/local/lib/python3.11/dist-packages/starlette/_exception_handler.py", line 51, in wrapped_app
#     await app(scope, receive, sender)
#   File "/usr/local/lib/python3.11/dist-packages/starlette/routing.py", line 73, in app
#     response = await f(request)
#                ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/fastapi/routing.py", line 301, in app
#     raw_response = await run_endpoint_function(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/fastapi/routing.py", line 212, in run_endpoint_function
#     return await dependant.call(**values)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/gradio/routes.py", line 1168, in upload_file
#     form = await multipart_parser.parse()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/gradio/route_utils.py", line 648, in parse
#     async for chunk in self.stream:
#   File "/usr/local/lib/python3.11/dist-packages/starlette/requests.py", line 228, in stream
#     raise ClientDisconnect()
# starlette.requests.ClientDisconnect
# Sorting videos/images
# Creating p1-2__temp.mp4 with 60.0 FPS...
# ['ffmpeg', '-hide_banner', '-hwaccel', 'auto', '-y', '-loglevel', 'error', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '4320x2160', '-pix_fmt', 'bgr24', '-r', '60.0', '-an', '-i', '-', '-vcodec', 'libx264', '-crf', '14', '-vf', 'colorspace=bt709:iall=bt601-6-625:fast=1', '-pix_fmt', 'yuv420p', '/content/roop-un/output/p1-2__temp.mp4']
# Processing:   0% 31/27000 [02:52<38:42:17,  5.17s/frames, memory_usage=03.13GB, execution_threads=4]Aborting processing - please wait for the remaining threads to be stopped
# Processing:   0% 36/27000 [03:08<23:06:11,  3.08s/frames, memory_usage=03.40GB, execution_threads=4]Sorting videos/images
# Creating p1-2__temp.mp4 with 60.0 FPS...
# ['ffmpeg', '-hide_banner', '-hwaccel', 'auto', '-y', '-loglevel', 'error', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '4320x2160', '-pix_fmt', 'bgr24', '-r', '60.0', '-an', '-i', '-', '-vcodec', 'libx264', '-crf', '14', '-vf', 'colorspace=bt709:iall=bt601-6-625:fast=1', '-pix_fmt', 'yuv420p', '/content/roop-un/output/p1-2__temp.mp4']
#
# Processing:   0% 38/27000 [03:55<46:26:15,  6.20s/frames, memory_usage=06.88GB, execution_threads=4]
#
# Processing:   0% 0/27000 [01:04<?, ?frames/s, memory_usage=05.35GB, execution_threads=10]
# Processing:   0% 1/27000 [01:04<484:41:53, 64.63s/frames, memory_usage=05.35GB, execution_threads=10]
# Processing:   0% 1/27000 [01:07<484:41:53, 64.63s/frames, memory_usage=05.13GB, execution_threads=10]
# Processing:   0% 2/27000 [01:07<213:36:14, 28.48s/frames, memory_usage=05.13GB, execution_threads=10]
# Processing:   0% 2/27000 [01:08<213:36:14, 28.48s/frames, memory_usage=05.39GB, execution_threads=10]
# Processing:   0% 3/27000 [01:08<118:41:37, 15.83s/frames, memory_usage=05.39GB, execution_threads=10]
# Processing:   0% 3/27000 [01:08<118:41:37, 15.83s/frames, memory_usage=05.16GB, execution_threads=10]
# Processing:   0% 4/27000 [01:08<73:03:26,  9.74s/frames, memory_usage=05.16GB, execution_threads=10]
# Processing:   0% 4/27000 [01:09<73:03:26,  9.74s/frames, memory_usage=04.98GB, execution_threads=10]
# Processing:   0% 5/27000 [01:09<48:10:05,  6.42s/frames, memory_usage=04.98GB, execution_threads=10]
# Processing:   0% 5/27000 [01:11<48:10:05,  6.42s/frames, memory_usage=05.01GB, execution_threads=10]
# Processing:   0% 6/27000 [01:11<37:08:24,  4.95s/frames, memory_usage=05.01GB, execution_threads=10]
# Processing:   0% 6/27000 [01:11<37:08:24,  4.95s/frames, memory_usage=04.87GB, execution_threads=10]
# Processing:   0% 7/27000 [01:14<37:08:19,  4.95s/frames, memory_usage=04.72GB, execution_threads=10]
# Processing:   0% 8/27000 [01:14<23:45:35,  3.17s/frames, memory_usage=04.72GB, execution_threads=10]
# Processing:   0% 8/27000 [01:22<23:45:35,  3.17s/frames, memory_usage=05.17GB, execution_threads=10]
# Processing:   0% 9/27000 [01:22<33:13:39,  4.43s/frames, memory_usage=05.17GB, execution_threads=10]
# Processing:   0% 9/27000 [01:22<33:13:39,  4.43s/frames, memory_usage=05.06GB, execution_threads=10]
# Processing:   0% 10/27000 [01:22<25:36:15,  3.42s/frames, memory_usage=05.06GB, execution_threads=10]
# Processing:   0% 10/27000 [01:41<25:36:15,  3.42s/frames, memory_usage=05.35GB, execution_threads=10]
# Processing:   0% 11/27000 [01:41<56:32:21,  7.54s/frames, memory_usage=05.35GB, execution_threads=10]
# Processing:   0% 11/27000 [01:48<56:32:21,  7.54s/frames, memory_usage=05.45GB, execution_threads=10]
# Processing:   0% 12/27000 [01:48<55:13:57,  7.37s/frames, memory_usage=05.45GB, execution_threads=10]
# Processing:   0% 12/27000 [01:49<55:13:57,  7.37s/frames, memory_usage=05.79GB, execution_threads=10]
# Processing:   0% 13/27000 [01:49<41:21:30,  5.52s/frames, memory_usage=05.79GB, execution_threads=10]
# Processing:   0% 13/27000 [01:53<41:21:30,  5.52s/frames, memory_usage=05.03GB, execution_threads=10]
# Processing:   0% 14/27000 [01:53<38:56:28,  5.19s/frames, memory_usage=05.03GB, execution_threads=10]
# Processing:   0% 14/27000 [01:54<38:56:28,  5.19s/frames, memory_usage=05.02GB, execution_threads=10]
# Processing:   0% 15/27000 [01:54<30:07:51,  4.02s/frames, memory_usage=05.02GB, execution_threads=10]
# Processing:   0% 15/27000 [01:55<30:07:51,  4.02s/frames, memory_usage=05.88GB, execution_threads=10]
# Processing:   0% 16/27000 [01:55<24:00:57,  3.20s/frames, memory_usage=05.88GB, execution_threads=10]
# Processing:   0% 16/27000 [01:56<24:00:57,  3.20s/frames, memory_usage=05.64GB, execution_threads=10]
# Processing:   0% 17/27000 [01:56<18:09:09,  2.42s/frames, memory_usage=05.64GB, execution_threads=10]
# Processing:   0% 17/27000 [01:58<18:09:09,  2.42s/frames, memory_usage=04.49GB, execution_threads=10]
# Processing:   0% 18/27000 [01:58<15:57:47,  2.13s/frames, memory_usage=04.49GB, execution_threads=10]
# Processing:   0% 18/27000 [02:15<15:57:47,  2.13s/frames, memory_usage=05.37GB, execution_threads=10]
# Processing:   0% 19/27000 [02:15<49:46:21,  6.64s/frames, memory_usage=05.37GB, execution_threads=10]
# Processing:   0% 19/27000 [02:15<49:46:21,  6.64s/frames, memory_usage=05.32GB, execution_threads=10]
# Processing:   0% 20/27000 [02:15<35:54:44,  4.79s/frames, memory_usage=05.32GB, execution_threads=10]
# Processing:   0% 20/27000 [02:27<35:54:44,  4.79s/frames, memory_usage=04.70GB, execution_threads=10]
# Processing:   0% 21/27000 [02:27<51:07:20,  6.82s/frames, memory_usage=04.70GB, execution_threads=10]
# Processing:   0% 21/27000 [02:28<51:07:20,  6.82s/frames, memory_usage=04.89GB, execution_threads=10]
# Processing:   0% 22/27000 [02:28<38:53:22,  5.19s/frames, memory_usage=04.89GB, execution_threads=10]
# Processing:   0% 22/27000 [02:29<38:53:22,  5.19s/frames, memory_usage=04.95GB, execution_threads=10]
# Processing:   0% 23/27000 [02:29<29:44:38,  3.97s/frames, memory_usage=04.95GB, execution_threads=10]
# Processing:   0% 23/27000 [02:33<29:44:38,  3.97s/frames, memory_usage=06.23GB, execution_threads=10]
# Processing:   0% 24/27000 [02:33<30:07:41,  4.02s/frames, memory_usage=06.23GB, execution_threads=10]
# Processing:   0% 24/27000 [02:41<30:07:41,  4.02s/frames, memory_usage=05.51GB, execution_threads=10]
# Processing:   0% 25/27000 [02:41<38:33:27,  5.15s/frames, memory_usage=05.51GB, execution_threads=10]
# Processing:   0% 25/27000 [02:48<38:33:27,  5.15s/frames, memory_usage=05.74GB, execution_threads=10]
# Processing:   0% 26/27000 [02:48<41:52:08,  5.59s/frames, memory_usage=05.74GB, execution_threads=10]
# Processing:   0% 26/27000 [02:49<41:52:08,  5.59s/frames, memory_usage=06.03GB, execution_threads=10]
# Processing:   0% 27/27000 [02:49<31:50:49,  4.25s/frames, memory_usage=06.03GB, execution_threads=10]
# Processing:   0% 27/27000 [02:52<31:50:49,  4.25s/frames, memory_usage=05.35GB, execution_threads=10]
# Processing:   0% 28/27000 [02:52<30:03:24,  4.01s/frames, memory_usage=05.35GB, execution_threads=10]
# Processing:   0% 28/27000 [02:54<30:03:24,  4.01s/frames, memory_usage=05.75GB, execution_threads=10]
# Processing:   0% 29/27000 [02:54<23:58:40,  3.20s/frames, memory_usage=05.75GB, execution_threads=10]
# Processing:   0% 29/27000 [02:58<23:58:40,  3.20s/frames, memory_usage=04.88GB, execution_threads=10]
# Processing:   0% 30/27000 [02:58<25:32:34,  3.41s/frames, memory_usage=04.88GB, execution_threads=10]
# Processing:   0% 30/27000 [03:20<25:32:34,  3.41s/frames, memory_usage=05.84GB, execution_threads=10]
# Processing:   0% 31/27000 [03:20<68:21:31,  9.12s/frames, memory_usage=05.84GB, execution_threads=10]
# Processing:   0% 31/27000 [03:21<68:21:31,  9.12s/frames, memory_usage=05.37GB, execution_threads=10]
# Processing:   0% 32/27000 [03:21<49:17:54,  6.58s/frames, memory_usage=05.37GB, execution_threads=10]
# Processing:   0% 32/27000 [03:23<49:17:54,  6.58s/frames, memory_usage=04.95GB, execution_threads=10]
# Processing:   0% 33/27000 [03:23<40:06:30,  5.35s/frames, memory_usage=04.95GB, execution_threads=10]
# Processing:   0% 33/27000 [03:25<40:06:30,  5.35s/frames, memory_usage=05.40GB, execution_threads=10]
# Processing:   0% 34/27000 [03:25<32:57:16,  4.40s/frames, memory_usage=05.40GB, execution_threads=10]
# Processing:   0% 34/27000 [03:36<32:57:16,  4.40s/frames, memory_usage=04.87GB, execution_threads=10]
# Processing:   0% 35/27000 [03:36<46:01:38,  6.14s/frames, memory_usage=04.87GB, execution_threads=10]
# Processing:   0% 35/27000 [03:41<46:01:38,  6.14s/frames, memory_usage=05.61GB, execution_threads=10]
# Processing:   0% 36/27000 [03:41<43:43:41,  5.84s/frames, memory_usage=05.61GB, execution_threads=10]
# Processing:   0% 36/27000 [03:41<43:43:41,  5.84s/frames, memory_usage=05.50GB, execution_threads=10]
# Processing:   0% 37/27000 [03:41<31:08:32,  4.16s/frames, memory_usage=05.50GB, execution_threads=10]Aborting processing - please wait for the remaining threads to be stopped
#
# Processing:   0% 37/27000 [03:43<31:08:32,  4.16s/frames, memory_usage=05.35GB, execution_threads=10]
# Processing:   0% 38/27000 [03:43<25:24:52,  3.39s/frames, memory_usage=05.35GB, execution_threads=10]
# Processing:   0% 38/27000 [03:44<25:24:52,  3.39s/frames, memory_usage=05.28GB, execution_threads=10]
# Processing:   0% 39/27000 [03:44<21:29:56,  2.87s/frames, memory_usage=05.28GB, execution_threads=10]
# Processing:   0% 39/27000 [03:44<21:29:56,  2.87s/frames, memory_usage=05.18GB, execution_threads=10]
# Processing:   0% 40/27000 [03:44<15:33:55,  2.08s/frames, memory_usage=05.18GB, execution_threads=10]Warning: unknown mime-type for "/content/roop-un/output" -- using "application/octet-stream"
# Error: no "view" mailcap rules found for type "application/octet-stream"
# /usr/bin/xdg-open: 882: www-browser: not found
# /usr/bin/xdg-open: 882: links2: not found
# /usr/bin/xdg-open: 882: elinks: not found
# /usr/bin/xdg-open: 882: links: not found
# /usr/bin/xdg-open: 882: lynx: not found
# /usr/bin/xdg-open: 882: w3m: not found
# xdg-open: no method available for opening '/content/roop-un/output'
# Warning: unknown mime-type for "/content/roop-un/output" -- using "application/octet-stream"
# Error: no "view" mailcap rules found for type "application/octet-stream"
# /usr/bin/xdg-open: 882: www-browser: not found
# /usr/bin/xdg-open: 882: links2: not found
# /usr/bin/xdg-open: 882: elinks: not found
# /usr/bin/xdg-open: 882: links: not found
# /usr/bin/xdg-open: 882: lynx: not found
# /usr/bin/xdg-open: 882: w3m: not found
# xdg-open: no method available for opening '/content/roop-un/output'
#
# Processing:   0% 40/27000 [04:23<15:33:55,  2.08s/frames, memory_usage=05.10GB, execution_threads=10]
# Processing:   0% 41/27000 [04:23<98:00:52, 13.09s/frames, memory_usage=05.10GB, execution_threads=10]
# Processing:   0% 41/27000 [04:23<98:00:52, 13.09s/frames, memory_usage=04.96GB, execution_threads=10]
# Processing:   0% 42/27000 [04:28<98:00:39, 13.09s/frames, memory_usage=05.74GB, execution_threads=10]
# Processing:   0% 43/27000 [04:28<61:01:29,  8.15s/frames, memory_usage=05.74GB, execution_threads=10]
# Processing:   0% 43/27000 [04:30<61:01:29,  8.15s/frames, memory_usage=06.15GB, execution_threads=10]
# Processing:   0% 44/27000 [04:30<50:18:50,  6.72s/frames, memory_usage=06.15GB, execution_threads=10]
# Processing:   0% 44/27000 [04:40<50:18:50,  6.72s/frames, memory_usage=05.54GB, execution_threads=10]
# Processing:   0% 45/27000 [04:40<55:14:51,  7.38s/frames, memory_usage=05.54GB, execution_threads=10]
# Processing:   0% 45/27000 [04:40<55:14:51,  7.38s/frames, memory_usage=05.43GB, execution_threads=10]
# Processing:   0% 46/27000 [04:40<55:14:43,  7.38s/frames, memory_usage=05.03GB, execution_threads=10]
# Processing:   0% 47/27000 [04:40<32:13:34,  4.30s/frames, memory_usage=05.03GB, execution_threads=10]
# Processing:   0% 47/27000 [04:40<32:13:34,  4.30s/frames, memory_usage=04.97GB, execution_threads=10]
# Processing:   0% 48/27000 [04:40<24:56:46,  3.33s/frames, memory_usage=04.97GB, execution_threads=10]
# Processing:   0% 48/27000 [04:41<24:56:46,  3.33s/frames, memory_usage=05.22GB, execution_threads=10]
# Processing:   0% 49/27000 [04:41<20:26:49,  2.73s/frames, memory_usage=05.22GB, execution_threads=10]
# Processing:   0% 49/27000 [04:42<20:26:49,  2.73s/frames, memory_usage=04.56GB, execution_threads=10]
# Processing:   0% 50/27000 [04:42<17:22:55,  2.32s/frames, memory_usage=04.56GB, execution_threads=10]
# Processing:   0% 50/27000 [04:58<17:22:55,  2.32s/frames, memory_usage=04.68GB, execution_threads=10]
# Processing:   0% 51/27000 [04:58<44:59:36,  6.01s/frames, memory_usage=04.68GB, execution_threads=10]
# Processing:   0% 51/27000 [04:59<44:59:36,  6.01s/frames, memory_usage=04.81GB, execution_threads=10]
# Processing:   0% 52/27000 [04:59<33:47:44,  4.51s/frames, memory_usage=04.81GB, execution_threads=10]
# Processing:   0% 52/27000 [05:05<33:47:44,  4.51s/frames, memory_usage=04.63GB, execution_threads=10]
# Processing:   0% 53/27000 [05:05<37:34:24,  5.02s/frames, memory_usage=04.63GB, execution_threads=10]
# Processing:   0% 53/27000 [05:06<37:34:24,  5.02s/frames, memory_usage=04.80GB, execution_threads=10]
# Processing:   0% 54/27000 [05:06<27:53:00,  3.73s/frames, memory_usage=04.80GB, execution_threads=10]
# Processing:   0% 54/27000 [05:06<27:53:00,  3.73s/frames, memory_usage=04.47GB, execution_threads=10]
# Processing:   0% 55/27000 [05:10<42:16:04,  5.65s/frames, memory_usage=04.47GB, execution_threads=10]
# Processing stopped!
# Processing stopped!
# Sorting videos/images
# Creating p1-2__temp.mp4 with 60.0 FPS...
# ['ffmpeg', '-hide_banner', '-hwaccel', 'auto', '-y', '-loglevel', 'error', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '4320x2160', '-pix_fmt', 'bgr24', '-r', '60.0', '-an', '-i', '-', '-vcodec', 'libx264', '-crf', '14', '-vf', 'colorspace=bt709:iall=bt601-6-625:fast=1', '-pix_fmt', 'yuv420p', '/content/roop-un/output/p1-2__temp.mp4']
# Processing:   1% 355/27000 [31:48<47:30:19,  6.42s/frames, memory_usage=04.01GB, execution_threads=2]Aborting processing - please wait for the remaining threads to be stopped
# Processing:   1% 359/27000 [32:08<39:45:18,  5.37s/frames, memory_usage=04.01GB, execution_threads=2]
# Processing stopped!
# Killing tunnel 127.0.0.1:7860 <> https://bb5ea6e2d9cae7d574.gradio.live

# %% [markdown]
# ### Download generated images folder
# (only needed if you want to zip the generated output)

# %%
import shutil
import os
from google.colab import files

def zip_directory(directory_path, zip_path):
    shutil.make_archive(zip_path, 'zip', directory_path)

# Set the directory path you want to download
directory_path = '/content/roop-unleashed/output'

# Set the zip file name
zip_filename = 'fake_output.zip'

# Zip the directory
zip_directory(directory_path, zip_filename)

# Download the zip file
files.download(zip_filename+'.zip')
